# %% [markdown]
# <a href="https://colab.research.google.com/github/joelinho10/Inteligencia-Artificial/blob/main/Exercises_about_Pandas_Lib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS HAS TWO DATA STRUCTURE
import pandas as pd
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %% [markdown]
# Movies='pegar ruta'
# Movies=pd.read_csv(movies)

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags.head(3)
# Out:
#    userId  movieId          tag   timestamp
# 0      18     4141  Mark Waters  1240597180
# 1      65      208    dark hero  1368150078
# 2      65      353    dark hero  1368150079

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819

# %%
ratings.shape
# Out:
# (2000000, 4)

# %%
movies.shape
# Out:
# (27278, 3)

# %%
tags.shape
# Out:
# (465564, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(5)
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
ratings.tail(5)
# Out:
#          userId  movieId  rating
# 1999995   13567    59725     3.5
# 1999996   13567    63062     5.0
# 1999997   13567    64957     5.0
# 1999998   13567    65216     4.5
# 1999999   13567    66203     4.0

# %%
ratings.iloc[6]
# Out:
# userId       1.0
# movieId    151.0
# rating       4.0
# Name: 6, dtype: float64

# %%
ratings.iloc[[20,30,50]]
# Out:
#     userId  movieId  rating
# 20       1      924     3.5
# 30       1     1196     4.5
# 50       1     1291     3.5

# %%
print(ratings.iloc[[30,40,50]])
# Out:
#     userId  movieId  rating
# 30       1     1196     4.5
# 40       1     1240     4.0
# 50       1     1291     3.5

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000000e+06  2.000000e+06  2.000000e+06
# mean   6.763309e+03  8.717178e+03  3.518678e+00
# std    3.908996e+03  1.921823e+04  1.050556e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.374000e+03  9.040000e+02  3.000000e+00
# 50%    6.743000e+03  2.153000e+03  3.500000e+00
# 75%    1.015825e+04  4.661000e+03  4.000000e+00
# max    1.356700e+04  1.307680e+05  5.000000e+00

# %%
print(ratings['rating'].min())
# Out:
# 0.5

# %%
print(ratings['rating'].max())
# Out:
# 5.0

# %%
print(ratings['rating'].mean())
# Out:
# 3.51867825

# %%
print(ratings['rating'].std())
# Out:
# 1.0505561859372814

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.005013 -0.005718
# movieId  0.005013  1.000000  0.003717
# rating  -0.005718  0.003717  1.000000

# %%
filter = ratings['rating']>5
print (filter)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1999995    False
# 1999996    False
# 1999997    False
# 1999998    False
# 1999999    False
# Name: rating, Length: 2000000, dtype: bool

# %%
filter.any()
# Out:
# False

# %%
mask=ratings['rating']>0

# %%
print(mask.any())
# Out:
# True

# %%
mask=ratings['rating']<3

# %%
print(mask.any())
# Out:
# True

# %%
aux=ratings[mask]
print(aux.shape)
# Out:
# (354798, 3)

# %%
print(aux.head(3))
# Out:
#      userId  movieId  rating
# 186       2      891     2.0
# 203       2     1969     2.0
# 204       2     1970     2.0

# %%
ratings.shape
# Out:
# (2000000, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
ratings.hist(column= 'rating',figsize=(15,6))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.head(3)
# Out:
#    userId  movieId          tag
# 0      18     4141  Mark Waters
# 1      65      208    dark hero
# 2      65      353    dark hero

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
animation = movies['genres'].str.contains('Animation')

# %%
newMovies=movies[animation]

# %%
newMovies.shape
# Out:
# (1027, 3)

# %%
newMovies.head(10)
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 47          Animation|Children|Drama|Musical|Romance
# 236                Animation|Children|Comedy|Romance
# 241                               Animation|Children
# 310                               Animation|Children
# 360  Adventure|Animation|Children|Drama|Musical|IMAX
# 388                              Adventure|Animation
# 547               Animation|Children|Fantasy|Musical
# 553      Action|Adventure|Animation|Children|Fantasy

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag   timestamp
# 0      18     4141  Mark Waters  1240597180
# 1      65      208    dark hero  1368150078
# 2      65      353    dark hero  1368150079

# %%
tags['informationDateTime']= pd.to_datetime(tags['timestamp'],unit='s')

# %%
tags.head(5)
# Out:
#    userId  movieId            tag   timestamp informationDateTime
# 0      18     4141    Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208      dark hero  1368150078 2013-05-10 01:41:18
# 2      65      353      dark hero  1368150079 2013-05-10 01:41:19
# 3      65      521  noir thriller  1368149983 2013-05-10 01:39:43
# 4      65      592      dark hero  1368150078 2013-05-10 01:41:18
